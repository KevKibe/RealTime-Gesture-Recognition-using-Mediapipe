# %%
# !pip install pyyaml==5.3.1

# %%
# !pip install gdown

# %%
# !pip install mediapipe-model-maker

# %%
import os
import random
import tensorflow as tf
from mediapipe_model_maker import gesture_recognizer
import shutil
import matplotlib.pyplot as plt

# %% [markdown]
# ## Getting the labels and examples

# %%
dataset_path = "/kaggle/input/combined-handgesture-dataset/combined_handgesture_dataset"
labels = []
for i in os.listdir(dataset_path):
    if os.path.isdir(os.path.join(dataset_path, i)):
        labels.append(i)
print(len(labels))
print(labels)

NUM_EXAMPLES = 3

for label in labels:
  label_dir = os.path.join(dataset_path, label)
  example_filenames = os.listdir(label_dir)[:NUM_EXAMPLES]
  fig, axs = plt.subplots(1, NUM_EXAMPLES, figsize=(10,2))
  for i in range(NUM_EXAMPLES):
    axs[i].imshow(plt.imread(os.path.join(label_dir, example_filenames[i])))
    axs[i].get_xaxis().set_visible(False)
    axs[i].get_yaxis().set_visible(False)
  fig.suptitle(f'Showing {NUM_EXAMPLES} examples for {label}')

plt.show()
# Out:
# 22
# ['rocknroll', 'call', 'four', 'mute', 'paper', 'ok', 'rock', 'dislike', 'two_up', 'three2', 'three', 'one', 'two_up_inverted', 'stop', 'fist', 'scissors', 'palm', 'none', 'peace', 'peace_inverted', 'stop_inverted', 'like']
# /tmp/ipykernel_28/3876410456.py:14: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axs = plt.subplots(1, NUM_EXAMPLES, figsize=(10,2))

# %% [markdown]
# ## Data Preprocessing

# %%
data = gesture_recognizer.Dataset.from_folder(
    dirname=dataset_path,
    hparams=gesture_recognizer.HandDataPreprocessingParams()
)
train_data, rest_data = data.split(0.8)
validation_data, test_data = rest_data.split(0.5)
# Out:
# Downloading https://storage.googleapis.com/mediapipe-assets/palm_detection_full.tflite to /tmp/model_maker/gesture_recognizer/palm_detection_full.tflite
# Downloading https://storage.googleapis.com/mediapipe-assets/hand_landmark_full.tflite to /tmp/model_maker/gesture_recognizer/hand_landmark_full.tflite
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Downloading https://storage.googleapis.com/mediapipe-assets/gesture_embedder.tar.gz to /tmp/model_maker/gesture_recognizer/gesture_embedder

# %% [markdown]
# ## Benchmark Model

# %%
#benchmark model by the mediapipe team
hparams = gesture_recognizer.HParams(export_dir="baseline_model")
options = gesture_recognizer.GestureRecognizerOptions(hparams=hparams)
model = gesture_recognizer.GestureRecognizer.create(
    train_data=train_data,
    validation_data=validation_data,
    options=options
)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hand_embedding (InputLayer)  [(None, 128)]            0
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  re_lu (ReLU)                (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  custom_gesture_recognizer_o  (None, 22)               2838
#  ut (Dense)
#
# =================================================================
# Total params: 3,350
# Trainable params: 3,094
# Non-trainable params: 256
# _________________________________________________________________
# None
# Epoch 1/10
# 11100/11100 [==============================] - 179s 16ms/step - loss: 1.1857 - categorical_accuracy: 0.5990 - val_loss: 0.5767 - val_categorical_accuracy: 0.8220 - lr: 0.0010
# Epoch 2/10
# 11100/11100 [==============================] - 171s 15ms/step - loss: 0.9842 - categorical_accuracy: 0.6694 - val_loss: 0.5606 - val_categorical_accuracy: 0.8249 - lr: 9.9000e-04
# Epoch 3/10
# 11100/11100 [==============================] - 175s 16ms/step - loss: 0.9603 - categorical_accuracy: 0.6749 - val_loss: 0.5719 - val_categorical_accuracy: 0.8241 - lr: 9.8010e-04
# Epoch 4/10
# 11100/11100 [==============================] - 175s 16ms/step - loss: 0.9474 - categorical_accuracy: 0.6809 - val_loss: 0.5611 - val_categorical_accuracy: 0.8277 - lr: 9.7030e-04
# Epoch 5/10
# 11100/11100 [==============================] - 165s 15ms/step - loss: 0.9396 - categorical_accuracy: 0.6813 - val_loss: 0.5824 - val_categorical_accuracy: 0.8162 - lr: 9.6060e-04
# Epoch 6/10
# 11100/11100 [==============================] - 166s 15ms/step - loss: 0.9338 - categorical_accuracy: 0.6862 - val_loss: 0.5729 - val_categorical_accuracy: 0.8267 - lr: 9.5099e-04
# Epoch 7/10
# 11100/11100 [==============================] - 167s 15ms/step - loss: 0.9320 - categorical_accuracy: 0.6845 - val_loss: 0.5802 - val_categorical_accuracy: 0.8234 - lr: 9.4148e-04
# Epoch 8/10
# 11100/11100 [==============================] - 174s 16ms/step - loss: 0.9258 - categorical_accuracy: 0.6854 - val_loss: 0.5902 - val_categorical_accuracy: 0.8144 - lr: 9.3207e-04
# Epoch 9/10
# 11100/11100 [==============================] - 174s 16ms/step - loss: 0.9280 - categorical_accuracy: 0.6838 - val_loss: 0.5925 - val_categorical_accuracy: 0.8151 - lr: 9.2274e-04
# Epoch 10/10
# 11100/11100 [==============================] - 165s 15ms/step - loss: 0.9208 - categorical_accuracy: 0.6880 - val_loss: 0.6081 - val_categorical_accuracy: 0.8094 - lr: 9.1352e-04

# %%
loss, acc = model.evaluate(test_data, batch_size=1)
print(f"Test loss:{loss}, Test accuracy:{acc}")
# Out:
# 2776/2776 [==============================] - 89s 5ms/step - loss: 0.5311 - categorical_accuracy: 0.8347
# Test loss:0.531060516834259, Test accuracy:0.8346541523933411

# %%
model.export_model()

# %% [markdown]
# ## Custom model_1

# %%
hparams = gesture_recognizer.HParams(learning_rate=9.9000e-04,epochs= 25,batch_size= 16,
                                     shuffle = True, lr_decay = 0.99, export_dir="custom_model_1")

options = gesture_recognizer.GestureRecognizerOptions(hparams=hparams)
model = gesture_recognizer.GestureRecognizer.create(
    train_data=train_data,
    validation_data=validation_data,
    options=options
)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hand_embedding (InputLayer)  [(None, 128)]            0
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  custom_gesture_recognizer_o  (None, 22)               2838
#  ut (Dense)
#
# =================================================================
# Total params: 3,350
# Trainable params: 3,094
# Non-trainable params: 256
# _________________________________________________________________
# None
# Epoch 1/25
# 1387/1387 [==============================] - 154s 110ms/step - loss: 0.6938 - categorical_accuracy: 0.7616 - val_loss: 0.4333 - val_categorical_accuracy: 0.8332 - lr: 9.9000e-04
# Epoch 2/25
# 1387/1387 [==============================] - 147s 106ms/step - loss: 0.4603 - categorical_accuracy: 0.8233 - val_loss: 0.4022 - val_categorical_accuracy: 0.8429 - lr: 9.8010e-04
# Epoch 3/25
# 1387/1387 [==============================] - 148s 106ms/step - loss: 0.4372 - categorical_accuracy: 0.8305 - val_loss: 0.3822 - val_categorical_accuracy: 0.8494 - lr: 9.7030e-04
# Epoch 4/25
# 1387/1387 [==============================] - 148s 107ms/step - loss: 0.4242 - categorical_accuracy: 0.8353 - val_loss: 0.3710 - val_categorical_accuracy: 0.8519 - lr: 9.6060e-04
# Epoch 5/25
# 1387/1387 [==============================] - 147s 106ms/step - loss: 0.4115 - categorical_accuracy: 0.8388 - val_loss: 0.3695 - val_categorical_accuracy: 0.8548 - lr: 9.5099e-04
# Epoch 6/25
# 1387/1387 [==============================] - 147s 106ms/step - loss: 0.4064 - categorical_accuracy: 0.8390 - val_loss: 0.3645 - val_categorical_accuracy: 0.8548 - lr: 9.4148e-04
# Epoch 7/25
# 1387/1387 [==============================] - 156s 112ms/step - loss: 0.4003 - categorical_accuracy: 0.8405 - val_loss: 0.3601 - val_categorical_accuracy: 0.8526 - lr: 9.3207e-04
# Epoch 8/25
# 1387/1387 [==============================] - 155s 112ms/step - loss: 0.3966 - categorical_accuracy: 0.8441 - val_loss: 0.3601 - val_categorical_accuracy: 0.8559 - lr: 9.2274e-04
# Epoch 9/25
# 1387/1387 [==============================] - 149s 107ms/step - loss: 0.3937 - categorical_accuracy: 0.8437 - val_loss: 0.3570 - val_categorical_accuracy: 0.8555 - lr: 9.1352e-04
# Epoch 10/25
# 1387/1387 [==============================] - 157s 113ms/step - loss: 0.3919 - categorical_accuracy: 0.8432 - val_loss: 0.3557 - val_categorical_accuracy: 0.8577 - lr: 9.0438e-04
# Epoch 11/25
# 1387/1387 [==============================] - 150s 108ms/step - loss: 0.3892 - categorical_accuracy: 0.8431 - val_loss: 0.3565 - val_categorical_accuracy: 0.8562 - lr: 8.9534e-04
# Epoch 12/25
# 1387/1387 [==============================] - 152s 109ms/step - loss: 0.3874 - categorical_accuracy: 0.8441 - val_loss: 0.3544 - val_categorical_accuracy: 0.8591 - lr: 8.8638e-04
# Epoch 13/25
# 1387/1387 [==============================] - 151s 109ms/step - loss: 0.3860 - categorical_accuracy: 0.8446 - val_loss: 0.3541 - val_categorical_accuracy: 0.8559 - lr: 8.7752e-04
# Epoch 14/25
# 1387/1387 [==============================] - 149s 107ms/step - loss: 0.3847 - categorical_accuracy: 0.8459 - val_loss: 0.3527 - val_categorical_accuracy: 0.8580 - lr: 8.6875e-04
# Epoch 15/25
# 1387/1387 [==============================] - 149s 108ms/step - loss: 0.3829 - categorical_accuracy: 0.8455 - val_loss: 0.3514 - val_categorical_accuracy: 0.8595 - lr: 8.6006e-04
# Epoch 16/25
# 1387/1387 [==============================] - 150s 108ms/step - loss: 0.3804 - categorical_accuracy: 0.8463 - val_loss: 0.3498 - val_categorical_accuracy: 0.8577 - lr: 8.5146e-04
# Epoch 17/25
# 1387/1387 [==============================] - 149s 107ms/step - loss: 0.3812 - categorical_accuracy: 0.8449 - val_loss: 0.3516 - val_categorical_accuracy: 0.8577 - lr: 8.4294e-04
# Epoch 18/25
# 1387/1387 [==============================] - 149s 108ms/step - loss: 0.3802 - categorical_accuracy: 0.8476 - val_loss: 0.3501 - val_categorical_accuracy: 0.8569 - lr: 8.3451e-04
# Epoch 19/25
# 1387/1387 [==============================] - 156s 112ms/step - loss: 0.3838 - categorical_accuracy: 0.8463 - val_loss: 0.3517 - val_categorical_accuracy: 0.8569 - lr: 8.2617e-04
# Epoch 20/25
# 1387/1387 [==============================] - 155s 112ms/step - loss: 0.3795 - categorical_accuracy: 0.8479 - val_loss: 0.3465 - val_categorical_accuracy: 0.8584 - lr: 8.1791e-04
# Epoch 21/25
# 1387/1387 [==============================] - 151s 109ms/step - loss: 0.3765 - categorical_accuracy: 0.8499 - val_loss: 0.3497 - val_categorical_accuracy: 0.8577 - lr: 8.0973e-04
# Epoch 22/25
# 1387/1387 [==============================] - 150s 108ms/step - loss: 0.3743 - categorical_accuracy: 0.8485 - val_loss: 0.3473 - val_categorical_accuracy: 0.8587 - lr: 8.0163e-04
# Epoch 23/25
# 1387/1387 [==============================] - 151s 109ms/step - loss: 0.3759 - categorical_accuracy: 0.8455 - val_loss: 0.3449 - val_categorical_accuracy: 0.8605 - lr: 7.9361e-04
# Epoch 24/25
# 1387/1387 [==============================] - 155s 111ms/step - loss: 0.3776 - categorical_accuracy: 0.8473 - val_loss: 0.3461 - val_categorical_accuracy: 0.8591 - lr: 7.8568e-04
# Epoch 25/25
# 1387/1387 [==============================] - 157s 113ms/step - loss: 0.3721 - categorical_accuracy: 0.8496 - val_loss: 0.3454 - val_categorical_accuracy: 0.8587 - lr: 7.7782e-04

# %%
loss, acc = model.evaluate(test_data, batch_size=1)
print(f"Test loss:{loss}, Test accuracy:{acc}")
# Out:
# 2776/2776 [==============================] - 91s 5ms/step - loss: 0.2941 - categorical_accuracy: 0.8815
# Test loss:0.2940661609172821, Test accuracy:0.8814841508865356

# %% [markdown]
# **The accuracy is 88%**

# %%
model.export_model()
# Out:
# Downloading https://storage.googleapis.com/mediapipe-assets/gesture_embedder.tflite to /tmp/model_maker/gesture_recognizer/gesture_embedder.tflite
# Using existing files at /tmp/model_maker/gesture_recognizer/palm_detection_full.tflite
# Using existing files at /tmp/model_maker/gesture_recognizer/hand_landmark_full.tflite
# Downloading https://storage.googleapis.com/mediapipe-assets/canned_gesture_classifier.tflite to /tmp/model_maker/gesture_recognizer/canned_gesture_classifier.tflite

# %%
hparams = gesture_recognizer.HParams(learning_rate=8.6006e-04,epochs= 25,batch_size= 8,
                                     shuffle = True, lr_decay = 0.99, export_dir="custom_model_2")

options = gesture_recognizer.GestureRecognizerOptions(hparams=hparams)
custom_model_2 = gesture_recognizer.GestureRecognizer.create(
    train_data=train_data,
    validation_data=validation_data,
    options=options
)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hand_embedding (InputLayer)  [(None, 128)]            0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  custom_gesture_recognizer_o  (None, 22)               2838
#  ut (Dense)
#
# =================================================================
# Total params: 3,350
# Trainable params: 3,094
# Non-trainable params: 256
# _________________________________________________________________
# None
# Resuming from custom_model_2/epoch_models/model-0007
# Epoch 1/25
# 2775/2775 [==============================] - 155s 55ms/step - loss: 0.5276 - categorical_accuracy: 0.8030 - val_loss: 0.4018 - val_categorical_accuracy: 0.8393 - lr: 8.6006e-04
# Epoch 2/25
# 2775/2775 [==============================] - 153s 55ms/step - loss: 0.4826 - categorical_accuracy: 0.8167 - val_loss: 0.3963 - val_categorical_accuracy: 0.8422 - lr: 8.5146e-04
# Epoch 3/25
# 2775/2775 [==============================] - 154s 55ms/step - loss: 0.4681 - categorical_accuracy: 0.8220 - val_loss: 0.3808 - val_categorical_accuracy: 0.8490 - lr: 8.4294e-04
# Epoch 4/25
# 2775/2775 [==============================] - 158s 57ms/step - loss: 0.4622 - categorical_accuracy: 0.8233 - val_loss: 0.3762 - val_categorical_accuracy: 0.8530 - lr: 8.3452e-04
# Epoch 5/25
# 2775/2775 [==============================] - 154s 55ms/step - loss: 0.4534 - categorical_accuracy: 0.8252 - val_loss: 0.3760 - val_categorical_accuracy: 0.8530 - lr: 8.2617e-04
# Epoch 6/25
# 2775/2775 [==============================] - 152s 55ms/step - loss: 0.4499 - categorical_accuracy: 0.8276 - val_loss: 0.3730 - val_categorical_accuracy: 0.8533 - lr: 8.1791e-04
# Epoch 7/25
# 2775/2775 [==============================] - 152s 55ms/step - loss: 0.4429 - categorical_accuracy: 0.8282 - val_loss: 0.3715 - val_categorical_accuracy: 0.8544 - lr: 8.0973e-04
# Epoch 8/25
# 2775/2775 [==============================] - 151s 54ms/step - loss: 0.4453 - categorical_accuracy: 0.8261 - val_loss: 0.3740 - val_categorical_accuracy: 0.8533 - lr: 8.0163e-04
# Epoch 9/25
# 2775/2775 [==============================] - 158s 57ms/step - loss: 0.4462 - categorical_accuracy: 0.8293 - val_loss: 0.3683 - val_categorical_accuracy: 0.8559 - lr: 7.9362e-04
# Epoch 10/25
# 2775/2775 [==============================] - 152s 55ms/step - loss: 0.4347 - categorical_accuracy: 0.8304 - val_loss: 0.3633 - val_categorical_accuracy: 0.8551 - lr: 7.8568e-04
# Epoch 11/25
# 2775/2775 [==============================] - 157s 57ms/step - loss: 0.4418 - categorical_accuracy: 0.8308 - val_loss: 0.3611 - val_categorical_accuracy: 0.8577 - lr: 7.7782e-04
# Epoch 12/25
# 2775/2775 [==============================] - 159s 57ms/step - loss: 0.4286 - categorical_accuracy: 0.8341 - val_loss: 0.3654 - val_categorical_accuracy: 0.8537 - lr: 7.7004e-04
# Epoch 13/25
# 2775/2775 [==============================] - 152s 55ms/step - loss: 0.4312 - categorical_accuracy: 0.8322 - val_loss: 0.3633 - val_categorical_accuracy: 0.8533 - lr: 7.6234e-04
# Epoch 14/25
# 2775/2775 [==============================] - 158s 57ms/step - loss: 0.4266 - categorical_accuracy: 0.8340 - val_loss: 0.3656 - val_categorical_accuracy: 0.8530 - lr: 7.5472e-04
# Epoch 15/25
# 2775/2775 [==============================] - 151s 54ms/step - loss: 0.4290 - categorical_accuracy: 0.8320 - val_loss: 0.3643 - val_categorical_accuracy: 0.8544 - lr: 7.4717e-04
# Epoch 16/25
# 2775/2775 [==============================] - 152s 55ms/step - loss: 0.4326 - categorical_accuracy: 0.8326 - val_loss: 0.3618 - val_categorical_accuracy: 0.8551 - lr: 7.3970e-04
# Epoch 17/25
# 2775/2775 [==============================] - 153s 55ms/step - loss: 0.4275 - categorical_accuracy: 0.8324 - val_loss: 0.3659 - val_categorical_accuracy: 0.8551 - lr: 7.3230e-04
# Epoch 18/25
# 2775/2775 [==============================] - 153s 55ms/step - loss: 0.4300 - categorical_accuracy: 0.8327 - val_loss: 0.3620 - val_categorical_accuracy: 0.8573 - lr: 7.2498e-04
# Epoch 19/25
# 2775/2775 [==============================] - 151s 54ms/step - loss: 0.4274 - categorical_accuracy: 0.8325 - val_loss: 0.3641 - val_categorical_accuracy: 0.8566 - lr: 7.1773e-04
# Epoch 20/25
# 2775/2775 [==============================] - 159s 57ms/step - loss: 0.4278 - categorical_accuracy: 0.8317 - val_loss: 0.3596 - val_categorical_accuracy: 0.8566 - lr: 7.1055e-04
# Epoch 21/25
# 2775/2775 [==============================] - 158s 57ms/step - loss: 0.4275 - categorical_accuracy: 0.8326 - val_loss: 0.3617 - val_categorical_accuracy: 0.8555 - lr: 7.0345e-04
# Epoch 22/25
# 2775/2775 [==============================] - 159s 57ms/step - loss: 0.4275 - categorical_accuracy: 0.8337 - val_loss: 0.3599 - val_categorical_accuracy: 0.8569 - lr: 6.9641e-04
# Epoch 23/25
# 2775/2775 [==============================] - 159s 57ms/step - loss: 0.4283 - categorical_accuracy: 0.8309 - val_loss: 0.3586 - val_categorical_accuracy: 0.8587 - lr: 6.8945e-04
# Epoch 24/25
# 2775/2775 [==============================] - 154s 56ms/step - loss: 0.4237 - categorical_accuracy: 0.8347 - val_loss: 0.3590 - val_categorical_accuracy: 0.8573 - lr: 6.8256e-04
# Epoch 25/25
# 2775/2775 [==============================] - 154s 55ms/step - loss: 0.4195 - categorical_accuracy: 0.8339 - val_loss: 0.3602 - val_categorical_accuracy: 0.8587 - lr: 6.7573e-04

# %%
loss, acc = custom_model_2.evaluate(test_data, batch_size=1)
print(f"Test loss:{loss}, Test accuracy:{acc}")
# Out:
# 2776/2776 [==============================] - 91s 5ms/step - loss: 0.3072 - categorical_accuracy: 0.8775
# Test loss:0.3071754574775696, Test accuracy:0.8775216341018677

# %% [markdown]
# **The accuracy is 87%**

# %%
custom_model_2.export_model()
# Out:
# Using existing files at /tmp/model_maker/gesture_recognizer/gesture_embedder.tflite
# Using existing files at /tmp/model_maker/gesture_recognizer/palm_detection_full.tflite
# Using existing files at /tmp/model_maker/gesture_recognizer/hand_landmark_full.tflite
# Using existing files at /tmp/model_maker/gesture_recognizer/canned_gesture_classifier.tflite
